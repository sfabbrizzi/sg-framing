# %%
import pandas as pd
import numpy as np
import random

from IPython.display import display, Image
from pigeon import annotate

from collections import defaultdict
from pathlib import Path
from typing import List
from matplotlib import pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ROOT: Path = Path("../")
DATA: Path = ROOT / "data"
VISUAL_GENOME: Path = DATA / "visual_genome"
IMAGES: Path = VISUAL_GENOME / "images" / "VG_100K"
RESULTS: Path = ROOT / "results"

SEED: int = 4567

# %%
List_of_FP_sport: List[int] = [2358758, 2321285, 2374678, 2397203, 2316400, 2408801, 2316427]
List_of_FP_work: List[int] = [2330263, 2348345, 2361732, 2406028, 2319723, 2405090, 2375523, 2341306]
List_of_FN_sport: List[int] = []
List_of_FN_work: List[int] = [2327442, 2405556, 2378327, 449, 2384384, 2317550, 2366461, 2380266, 2397913, 2329800, 2315562]

# %%
for i in List_of_FN_work:
    display(Image(IMAGES / f"{i}.jpg"))
    print()
